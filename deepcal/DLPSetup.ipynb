# %%
import vamtoolbox as vam

vam.dlp.setup.Focus(slices=20,N_screen=(1920,1080))
# Out:
# Line separation (inside edge) = 398 pixels
# half line thickness = 1, half line separation (center to center) = 200, center offset = 0
#
# Line separation (inside edge) = 398 pixels
# half line thickness = 1, half line separation (center to center) = 200, center offset = 0
#
# Line separation (inside edge) = 398 pixels
# half line thickness = 1, half line separation (center to center) = 200, center offset = 0
#
# Line separation (inside edge) = 398 pixels
# half line thickness = 1, half line separation (center to center) = 200, center offset = 0
#
# Line separation (inside edge) = 398 pixels
# half line thickness = 1, half line separation (center to center) = 200, center offset = 0
#
# Line separation (inside edge) = 398 pixels
# half line thickness = 1, half line separation (center to center) = 200, center offset = 0
#
# Line separation (inside edge) = 398 pixels
# half line thickness = 1, half line separation (center to center) = 200, center offset = 0
#
# ...

# %%
vam.dlp.setup.AxisAlignment(half_line_thickness=1,half_line_separation=400)
# Out:
# Line separation (inside edge) = 396 pixels
# half line thickness = 2, half line separation (center to center) = 200, center offset = 0
#
# Line separation (inside edge) = 398 pixels
# half line thickness = 1, half line separation (center to center) = 200, center offset = 0
#
# Line separation (inside edge) = 286 pixels
# half line thickness = 57, half line separation (center to center) = 200, center offset = 0
#
# Line separation (inside edge) = 350 pixels
# half line thickness = 8, half line separation (center to center) = 183, center offset = 0
#
# Line separation (inside edge) = 74 pixels
# half line thickness = 24, half line separation (center to center) = 61, center offset = 0
#
# Line separation (inside edge) = 394 pixels
# half line thickness = 3, half line separation (center to center) = 200, center offset = 0
#
# Line separation (inside edge) = 338 pixels
# half line thickness = 30, half line separation (center to center) = 199, center offset = 0
#
# ...
