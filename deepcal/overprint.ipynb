# %%
import vamtoolbox as vam
import numpy as np

target_geo = vam.geometry.TargetGeometry(stlfilename=vam.resources.load("screwdriver.stl"),resolution=200,bodies={'print':[2],'insert':[1]})
target_geo.show(show_bodies=True)

num_angles = 360
angles = np.linspace(0, 360 - 360 / num_angles, num_angles)
proj_geo = vam.geometry.ProjectionGeometry(angles,ray_type='parallel',CUDA=False)

optimizer_params = vam.optimize.Options(method='OSMO',n_iter=20,d_h=0.85,d_l=0.6,filter='hamming',verbose='plot')
opt_sino, opt_recon, error = vam.optimize.optimize(target_geo, proj_geo,optimizer_params)
opt_recon.show()
opt_sino.show()
# Out:
# c:\Users\Mark\anaconda3\envs\CALenv\lib\site-packages\pyglet\image\codecs\wic.py:406: UserWarning: [WinError -2147417850] Cannot change thread mode after it is set
#   warnings.warn(str(err))
# c:\Users\Mark\anaconda3\envs\CALenv\lib\site-packages\vamtoolbox\projector\Projector3DParallel.py:117: RuntimeWarning: All-NaN slice encountered
#   occ_sinogram[:, i, z_i] = np.nanmin(s_occ,axis=0)
# c:\Users\Mark\anaconda3\envs\CALenv\lib\site-packages\vamtoolbox\util\data.py:116: ComplexWarning: Casting complex values to real discards the imaginary part
#   return x_filtered.astype(float)
# Iteration    1 at time: 1468.3 s
# Iteration    2 at time: 2416.7 s
# Iteration    3 at time: 3400.9 s
# Iteration    4 at time: 4365.2 s
# Iteration    5 at time: 5784.6 s
# Iteration    6 at time: 6729.6 s
# Iteration    7 at time: 7661.9 s
# Iteration    8 at time: 8622.6 s
# Iteration    9 at time: 9577.0 s
# Iteration   10 at time: 10545.5 s
# Iteration   11 at time: 11488.1 s
# Iteration   12 at time: 12407.4 s
# Iteration   13 at time: 13382.2 s
# Iteration   14 at time: 14359.1 s
# Iteration   15 at time: 15350.0 s
# Iteration   16 at time: 16309.0 s
# Iteration   17 at time: 22093.0 s
# Iteration   18 at time: 22492.7 s
# Iteration   19 at time: 24345.9 s
# Iteration   19 at time: 24345.9 s
